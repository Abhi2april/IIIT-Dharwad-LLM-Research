# %%
# %%capture
# !mamba install --force-reinstall aiohttp -y
# !pip install -U "xformers<0.0.26" --index-url https://download.pytorch.org/whl/cu121
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"

# Temporary fix for https://github.com/huggingface/datasets/issues/6753
# !pip install datasets==2.16.0 fsspec==2023.10.0 gcsfs==2023.10.0

import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 
dtype = None 
load_in_4bit = True 

fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/llama-2-13b-bnb-4bit",
    "unsloth/codellama-34b-bnb-4bit",
    "unsloth/tinyllama-bnb-4bit",
] 

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/mistral-7b-bnb-4bit", 
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2024-08-08 08:48:21.304781: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-08 08:48:21.304881: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-08 08:48:21.437301: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ==((====))==  Unsloth 2024.8: Fast Mistral patching. Transformers = 4.44.0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.2+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.25.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/155 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, 
    bias = "none",    
    use_gradient_checkpointing = True,
    random_state = 3407,
    use_rslora = False,   
    loftq_config = None, 
)
# Out:
# Unsloth: Already have LoRA adapters! We shall skip this step.

# %%
from datasets import load_dataset
dataset = load_dataset("ABHISHEKSINGH0204/math_new", split = "train")
# Out:
# Resolving data files:   0%|          | 0/700 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/748 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/476 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/307 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/967 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/276 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.45k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/295 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/864 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/496 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/521 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/744 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/310 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/275 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/593 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/581 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/515 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/523 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/501 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/492 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/932 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/684 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/406 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/722 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/318 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/827 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/401 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/537 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/417 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/365 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/552 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/623 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/575 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/196 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/650 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/857 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/605 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/581 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/496 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/347 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/664 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/251 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/955 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/339 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/678 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/656 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/368 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/560 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/643 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/591 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/722 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/240 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/742 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/831 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/496 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/196 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/853 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/903 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.08k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/449 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/337 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/877 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/671 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/315 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/307 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/634 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/397 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/336 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/397 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/943 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/897 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/622 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/623 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/302 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/554 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/451 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/354 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/302 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/532 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/408 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/471 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/680 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/501 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/898 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/684 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/442 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/416 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/490 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/559 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/962 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/781 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/964 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/881 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.01k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/788 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/683 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/649 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/380 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/457 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/439 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/575 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/813 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/809 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/626 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/922 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/783 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/438 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/562 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/890 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/604 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/692 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/449 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/816 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/803 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/505 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/313 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/760 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/425 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.64k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/673 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/948 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/934 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/303 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/878 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/593 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/226 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/892 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/569 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/884 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/258 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/516 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/660 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/802 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/945 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.41k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/621 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.04k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/828 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/511 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.58k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.05k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/586 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.75k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/899 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/691 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/444 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.69k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/975 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/970 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/596 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.12k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/948 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1
[00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/946 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/725 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/839 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/676 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.71k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.30k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.27k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/360 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.34k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/283 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/651 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.83k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.11k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
def create_input_column(dataset):
    dataset['input'] = f"Generate a Question of {dataset['level']} and Type {dataset['type']}"
    return dataset

dataset = dataset.map(create_input_column)
# Out:
# Map:   0%|          | 0/700 [00:00<?, ? examples/s]

# %%
mathematics_prompt = """Below is an input query. Write a mathematics problem according to that input.

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    inputs       = examples["input"]
    outputs      = examples["problem"]
    texts = []
    for input, problem in zip(inputs, outputs):
        text = mathematics_prompt.format(input, problem) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/700 [00:00<?, ? examples/s]

# %%
print(dataset.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(dataset.head())
#
# AttributeError: 'Dataset' object has no attribute 'head'

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    packing=False,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=5,
        max_steps=50,
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        report_to="none",
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/700 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 4.5 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 700 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 50
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 05:02, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.450000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.267700</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.930200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.827600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.484600</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.269700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.094600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.776000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.926300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.963300</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.845400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.855800</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.985900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.797200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.801600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.793100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.739500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.962700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.755800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.769400</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.915700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.725200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.797300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.629100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.647700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.760000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.684700</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.790600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.756200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.863200</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.806300</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.731100</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.696400</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.842100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.721300</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.658800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.758000</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.794800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.784400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.712800</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.786900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.680600</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.751600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.706000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.780500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.764800</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.608600</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.665100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.820300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.689300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 310.8596 seconds used for training.
# 5.18 minutes used for training.
# Peak reserved memory = 6.504 GB.
# Peak reserved memory for training = 2.004 GB.
# Peak reserved memory % of max memory = 44.122 %.
# Peak reserved memory for training % of max memory = 13.595 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the input - leave the output blank!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    mathematics_prompt.format(
        "Generate a mathematics question containing a long story of calculus based on a round table and 2 people of level 5", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 264, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<s> Below is an input query. Write a mathematics problem according to that input.\n\n### Input:\nGenerate a mathematics question containing a long story of calculus based on a round table and 2 people of level 5\n\n### Response:\nA round table has a radius of 10 feet.  Two people are sitting at the table, one at each end.  The first person is 5 feet tall, and the second person is 6 feet tall.  The first person is sitting on a chair that is 2 feet tall, and the second person is sitting on a chair that is 3 feet tall.  What is the height of the table?</s>']

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    mathematics_prompt.format(
        "Generate a level 4 mathematics word problem question of type precalculus", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 512)
# Out:
# <s> Below is an input query. Write a mathematics problem according to that input.
#
# ### Input:
# Generate a level 4 mathematics word problem question of type precalculus
#
# ### Response:
# The point $P$ is the midpoint of the line segment with endpoints $A(1, 2, 3)$ and $B(4, 5, 6).$  The point $Q$ is the midpoint of the line segment with endpoints $P$ and $C(7, 8, 9).$  The point $R$ is the midpoint of the line segment with endpoints $Q$ and $D(10, 11, 12).$  What is the area of the parallelogram $ABCD?$</s>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", 
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) 

inputs = tokenizer(
[
    mathematics_prompt.format(
        "Generate a Question of Level 3 and Type Calculus", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
tokenizer.batch_decode(outputs)

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
